# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Знакомство-с-данными--и-их-предобработка" data-toc-modified-id="Знакомство-с-данными--и-их-предобработка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Знакомство с данными  и их предобработка</a></span></li><li><span><a href="#Создание-функций-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Создание-функций-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Создание функций для расчёта и анализа LTV, ROI, удержания и конверсии.</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Создание-профилей-пользователей" data-toc-modified-id="Создание-профилей-пользователей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создание профилей пользователей</a></span></li><li><span><a href="#Анализ-пользователей-по-странам" data-toc-modified-id="Анализ-пользователей-по-странам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ пользователей по странам</a></span></li><li><span><a href="#Анализ-пользователей-по-устройствам" data-toc-modified-id="Анализ-пользователей-по-устройствам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Анализ пользователей по устройствам</a></span></li><li><span><a href="#Анализ-пользователей-по-рекламным-каналам" data-toc-modified-id="Анализ-пользователей-по-рекламным-каналам-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Анализ пользователей по рекламным каналам</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span></li><li><span><a href="#Оценка-окупаемости-рекламы" data-toc-modified-id="Оценка-окупаемости-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости рекламы</a></span><ul class="toc-item"><li><span><a href="#Анализ-окупаемости-рекламы-в-целом" data-toc-modified-id="Анализ-окупаемости-рекламы-в-целом-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Анализ окупаемости рекламы в целом</a></span></li><li><span><a href="#Анализ-конверсии-и-удержания-пользователей" data-toc-modified-id="Анализ-конверсии-и-удержания-пользователей-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Анализ конверсии и удержания пользователей</a></span></li><li><span><a href="#Анализ-LTV,-ROI,-CAC--по-различным-признакам" data-toc-modified-id="Анализ-LTV,-ROI,-CAC--по-различным-признакам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Анализ LTV, ROI, CAC  по различным признакам</a></span></li><li><span><a href="#Выводы-по-5-разделу" data-toc-modified-id="Выводы-по-5-разделу-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Выводы по 5 разделу</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# ##  Знакомство с данными  и их предобработка ##

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import os

# %%
# Прочитаем файлы и сохраним их в соответствующих переменных
path = r'C:\Users\User\Desktop\Проекты курса\Проект №3'

visits = pd.read_csv(os.path.join(path, 'visits_info_short.csv'))
orders = pd.read_csv(os.path.join(path,'orders_info_short.csv'))
costs = pd.read_csv(os.path.join(path,'costs_info_short.csv'))

# %%
# Выведем первые 5 строк таблицы 'visits'

visits.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
# общая информация по датасету 'visits'

visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# Из данных таблицы 'visits' видно, что пропусков нет. Таблица включает в себя 6 столбцов и  309901 строку.
#
# Что необходимо исправить:
#
# 1. Названия столбцов привести к нижнему регистру.
# 2. Убрать пробелы.
# 3. Изменить тип данных в столбцах с датой на тип 'datetime'.

# %%
# Приведем названия столбцов к нижнему регистру

visits.columns = visits.columns.str.lower()
visits.columns
# Out:
# Index(['user id', 'region', 'device', 'channel', 'session start',
#        'session end'],
#       dtype='object')

# %%
# Уберем пробелы в названиях столбцов

visits = visits.rename(columns={'user id': 'user_id', 'session start': 'session_start', 'session end': 'session_end'})
visits.columns
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')

# %%
# Изменим тип данных в столбцах 'session_start' и 'session_end'

visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

# %%
# Проверим количество явных дубликатов в таблице 'visits'

visits.duplicated().sum()
# Out:
# 0

# %%
# Проверим есть ли неявные дубликаты

visits['region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
# уникальные значения по столбцу 'device'

visits['device'].unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
# уникальные значения по столбцу 'channel'

visits['channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %%
# После всех изменений отобразим еще раз общую информацию по таблице 'visits'

visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %%
# Выведем основные данные по таблице 'orders'

orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
# общая информация по датасету 'orders'

orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %% [markdown]
# Из данных таблицы 'orders' видно, что пропусков нет. Таблица включает в себя 3 столбца и 40212 строк.
#
# Что необходимо исправить:
#
# 1. Названия столбцов привести к нижнему регистру.
# 2. Убрать пробелы.
# 3. Изменить тип данных в столбце с датой на тип 'datetime'.

# %%
# Приводим наименования столбцов к нижнему регистру

orders.columns = orders.columns.str.lower()
orders.columns
# Out:
# Index(['user id', 'event dt', 'revenue'], dtype='object')

# %%
# Убираем пробелы в столбцах

orders = orders.rename(columns={'user id': 'user_id', 'event dt': 'event_dt'})

# %%
# Меняем тип данных в столбце 'event_dt'

orders['event_dt'] = pd.to_datetime(orders['event_dt'])

# %%
# Проверим если ли явные дубликаты в таблице 'orders'

orders.duplicated().sum()
# Out:
# 0

# %%
# После изменений выводим общую информацию таблицы 'orders'

orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %%
# Выведем первые 5 строк по таблице 'costs'

costs.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
# общая информация по датасету 'costs'

costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Из данных таблицы 'costs' видно, что пропусков нет. Таблица включает в себя 3 столбца и 1800 строк.
#
# Что необходимо исправить:
#
# 1. Названия столбцов привести к нижнему регистру.
# 2. Изменить тип данных в столбце с датой на тип 'datetime'.

# %%
# Приведем названия столбцов к нижнему регистру

costs.columns = costs.columns.str.lower()
costs.columns
# Out:
# Index(['dt', 'channel', 'costs'], dtype='object')

# %%
# Изменим тип данных столбца 'dt'

costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %%
# Проверим количество явных дубликатов в таблице 'costs'

costs.duplicated().sum()
# Out:
# 0

# %%
# Проверим есть ли неявные дубликаты в столбце 'channel'

costs['channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %%
# После изменений выведем еще раз общую информацию

costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# По итогу были выгружены 3 датасета: 'visits' (данные о посещениях), 'orders' (данные о покупках), 'costs' (данные о рекламных расходах).
#
# Были проведены следующие действия по отношению к данным таблиц:
#
# 1. Приведены названия столбцов к нижним регистрам.
# 2. Удалены пробелы из названия столбцов.
# 3. Все даты приведены к типу данных 'datetime' для дальнейшего анализа.
# 4. Были проверены данные на наличие явных и неявных дубликатов. По итогу дубликатов во всех трех таблицах нет.

# %%
# Выведем самую раннюю и самую позднюю даты по таблице 'orders'

print(f"Самая ранняя дата - {orders['event_dt'].min()}")
print(f"Самая поздняя дата - {orders['event_dt'].max()}")
# Out:
# Самая ранняя дата - 2019-05-01 00:28:11
# Самая поздняя дата - 2019-10-31 23:56:56

# %%
# Выведем самую раннюю и самую позднюю даты по таблице 'visits'

print(f"Самая ранняя дата - {visits['session_start'].min()}")
print(f"Самая поздняя дата - {visits['session_end'].max()}")
# Out:
# Самая ранняя дата - 2019-05-01 00:00:41
# Самая поздняя дата - 2019-11-01 01:38:46

# %%
# Выведем самую раннюю и самую позднюю даты по таблице 'costs'

print(f'Самая ранняя дата - {costs["dt"].min()}')
print(f'Самая поздняя дата - {costs["dt"].max()}')
# Out:
# Самая ранняя дата - 2019-05-01
# Самая поздняя дата - 2019-10-27

# %% [markdown]
# Выгрузив данные о ранних и поздних датах по трем таблицам, можно сделать вывод о том, что для анализа можно брать диапозон дат с 01.05.2019 по 27.10.2019, т.к. за этот период есть все данные в трех таблицах.

# %%
# Рассчитаем продолжительность сессии по каждому пользователю и переведем данные в секунды

visits['duration'] = (visits['session_end'] - visits['session_start']).dt.seconds

# Выведем общую информацию по данному столбцу

visits['duration'].describe()
# Out:
# count    309901.000000
# mean       1800.090868
# std        1803.063525
# min           0.000000
# 25%         517.000000
# 50%        1244.000000
# 75%        2497.000000
# max       22257.000000
# Name: duration, dtype: float64

# %%
# Количество пользователей, у которых время посещения 0 сек.

visits.query('duration == 0').shape[0]
# Out:
# 163

# %% [markdown]
# По данной информации можно сделать вывод о том, что данные корректно отражены. Окончание сессии позже, чем дата начала,как и должно быть. Также, есть пользователи, у которых время посещения равно 0 сек., это могло быть связано с техническими ошибками, как со стороны пользователей, так и со стороны приложения.

# %%
# Выведем основную информацию по столбцу 'costs' таблицы 'costs'

costs['costs'].describe()
# Out:
# count    1800.000000
# mean       58.609611
# std       107.740223
# min         0.800000
# 25%         6.495000
# 50%        12.285000
# 75%        33.600000
# max       630.000000
# Name: costs, dtype: float64

# %%
# Построим диаграмму размаха, чтобы увидеть,как распределены суммы

fig, ax = plt.subplots(figsize = (15,4))
ax = costs[['costs']].boxplot(vert = False, ax =ax)
ax.set_title('Диаграмма размаха по затрам на привлечения пользователей')
# Out:
# Text(0.5, 1.0, 'Диаграмма размаха по затрам на привлечения пользователей')

# %% [markdown]
# На данной диаграмме размаха можно увидеть много разных значений, которые вышли за пределы 'ящика с усами'. Это очень высокие затраты на привлечение пользователей, но таких сумм небольшое количество.
#
# Минимальная сумма составляет 0,8 у.е, максимальная - 630 у.е.

# %%
# Выведем основную информацию по столбцу 'orders' таблицы 'revenue'

orders['revenue'].describe()
# Out:
# count    40212.000000
# mean         5.370608
# std          3.454208
# min          4.990000
# 25%          4.990000
# 50%          4.990000
# 75%          4.990000
# max         49.990000
# Name: revenue, dtype: float64

# %% [markdown]
# Минимальная выручка и медиана имеют одинаковые значения и составляют 4.99, максимальная сумма - 49.99. Отрицательных значений нет, значит данные верно занесены в таблицу.

# %% [markdown]
# ## Создание функций для расчёта и анализа LTV, ROI, удержания и конверсии. ##
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# Напишем функции для создания пользовательских профилей, расчета Retention Rate (удержания), Conversion Rate (конверсии), LTV, ROI, а также функции для построения графиков.

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
# Функция для расчета удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# Напишем функции для визуализации удержания, конверсии, LTV и ROI.

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных ##

# %% [markdown]
# ###  Создание профилей пользователей ###

# %%
# Создадим профили пользователей и сохраним результат в переменную

profiles = get_profiles(visits, orders, costs)

profiles.head(5)
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
# Рассчитаем минимальную дату привлечения пользователей

profiles['dt'].min()
# Out:
# datetime.date(2019, 5, 1)

# %%
# Рассчитаем максимальную дату привлечения пользователей

profiles['dt'].max()
# Out:
# datetime.date(2019, 10, 27)

# %% [markdown]
# Диапазон дат для анализа данных выделен корректно в соответствие с требованием задания проекта,а также в соответствие с  периодом анализа данных, который был определен в первом разделе.

# %%
# Напишем функцию, которая поможет проанализировать пользователей по разным признакам

def profiles_attribute(df, column=[]):
    users_analise = df.pivot_table(index=column, columns='payer', values='user_id', aggfunc='count')\
    .rename(columns={False:'Неплатящие', True:'Платящие'})
    
    # Посчитаем общее количество пользователей
    users_analise['Всего пользователей'] = users_analise['Платящие'] + users_analise['Неплатящие']
    
    # Посчитаем долю пользователей
    users_analise['Доля пользователей, %'] = ((users_analise['Всего пользователей'] / users_analise['Всего пользователей'].sum())\
    * 100)
  
    # Рассчитаем долю платящих пользователей
    users_analise['Доля платящих, %'] = (users_analise['Платящие'] / users_analise['Всего пользователей']) * 100
    
    return users_analise.sort_values(by='Всего пользователей', ascending=False)

# %% [markdown]
# ### Анализ пользователей по странам ###

# %%
# Применим функцию для анализа пользователей по странам

users_region = profiles_attribute(profiles, ['region'])

users_region
# Out:
# payer          Неплатящие  Платящие  Всего пользователей  \
# region
# United States       93100      6902               100002
# UK                  16875       700                17575
# France              16787       663                17450
# Germany             14365       616                14981
#
# payer          Доля пользователей, %  Доля платящих, %
# region
# United States              66.664445          6.901862
# UK                         11.716042          3.982930
# France                     11.632713          3.799427
# Germany                     9.986801          4.111875

# %%
# Построим диаграммы по сводной таблице

users_region = users_region.reset_index()

plt.figure(figsize=(10, 5))

ax1 = plt.subplot(1,2,1)

sns.barplot(x=users_region['region'], y=users_region['Доля пользователей, %'], ax=ax1)

plt.title('Доля пользователей к общему числу', fontsize=13)

plt.xlabel('Страна', fontsize=12)

plt.ylabel('Доля пользователей, %', fontsize=12)


ax2 = plt.subplot(1,2,2)

sns.barplot(x=users_region['region'], y=users_region['Доля платящих, %'], ax=ax2)

plt.title('Доля платящих пользователей', fontsize=13)

plt.xlabel('Страна', fontsize=12)

plt.ylabel('Доля пользователей, %', fontsize=12);

# %% [markdown]
# В приложение пользователи приходили из таких стран, как США, Германия, Англия, Франция.
#
# Больше всего пользователей, в том числе платящих, из США. Доля платящих составляет 6.9 %, а доля пользователей 66.7 %.
#
# Меньше всего пользователей из Германии, их количество составляет 10 % от общего числа, а по доли платящих Германия занимает второе место после США, платящих пользователей 4 %.

# %% [markdown]
# ###  Анализ пользователей по устройствам ###

# %%
# Определим количество пользователей по каждому устройству

users_device = profiles_attribute(profiles, ['device'])
users_device
# Out:
# payer    Неплатящие  Платящие  Всего пользователей  Доля пользователей, %  \
# device
# iPhone        51097      3382                54479              36.317396
# Android       32982      2050                35032              23.353421
# PC            28918      1537                30455              20.302251
# Mac           28130      1912                30042              20.026932
#
# payer    Доля платящих, %
# device
# iPhone           6.207897
# Android          5.851793
# PC               5.046790
# Mac              6.364423

# %%
# Построим диаграммы по сводной таблице

users_device = users_device.reset_index()

plt.figure(figsize=(10, 5))

ax1 = plt.subplot(1,2,1)

sns.barplot(x=users_device['device'], y=users_device['Доля пользователей, %'], ax=ax1)

plt.title('Доля пользователей к общему числу', fontsize=13)

plt.xlabel('Устройство', fontsize=12)

plt.ylabel('Доля пользователей, %', fontsize=12)


ax2 = plt.subplot(1,2,2)

sns.barplot(x=users_device['device'], y=users_device['Доля платящих, %'], ax=ax2)

plt.title('Доля платящих пользователей', fontsize=13)

plt.xlabel('Устройство', fontsize=12)

plt.ylabel('Доля пользователей, %', fontsize=12);

# %% [markdown]
# В приложение пользователи заходили через такие устройства, как Mac, iPhone, Android, PC.
#
# Больше всего пользователей, которые заходили через iPhone, их количество составляет 54 479 человек или 36.3 %. Несмотря на это, доля платящих пользователей iPhone ниже на 0.15 %, чем доля платящих пользователей Mac. Пользователей Mac меньше всех, 30 042 человека или 20 %, но при этом доля платящих пользователей выше, чем по остальным устройствам и составляет 6.4 %.

# %% [markdown]
# ### Анализ пользователей по рекламным каналам ###

# %%
# Определим количество пользователей по каждому каналу привлечения

users_channel = profiles_attribute(profiles, ['channel'])
users_channel
# Out:
# payer               Неплатящие  Платящие  Всего пользователей  \
# channel
# organic                  55279      1160                56439
# FaceBoom                 25587      3557                29144
# TipTop                   17683      1878                19561
# OppleCreativeMedia        8372       233                 8605
# LeapBob                   8291       262                 8553
# WahooNetBanner            8100       453                 8553
# RocketSuperAds            4096       352                 4448
# MediaTornado              4208       156                 4364
# YRabbit                   4147       165                 4312
# AdNonSense                3440       440                 3880
# lambdaMediaAds            1924       225                 2149
#
# payer               Доля пользователей, %  Доля платящих, %
# channel
# organic                         37.623993          2.055316
# FaceBoom                        19.428297         12.204914
# ...

# %%
# Построим диаграммы по сводной таблице

users_channel = users_channel.reset_index()

plt.figure(figsize=(10, 5))
plt.subplots_adjust(wspace=0.8, hspace=0.8)

ax1 = plt.subplot(1,2,1)


sns.barplot(y=users_channel['channel'], x=users_channel['Доля пользователей, %'], ax=ax1, orient='h')

plt.title('Доля пользователей к общему числу', fontsize=13)

plt.xlabel('Доля пользователей, %', fontsize=12)

plt.ylabel('Рекламный источник', fontsize=12)


ax2 = plt.subplot(1,2,2)

sns.barplot(y=users_channel['channel'], x=users_channel['Доля платящих, %'].sort_values(ascending=False), ax=ax2, orient='h')

plt.title('Доля платящих пользователей', fontsize=13)

plt.xlabel('Доля пользователей, %', fontsize=12)

plt.ylabel('Рекламный источник', fontsize=12);

# %% [markdown]
# Больше всего органических пользователей, которые скачали и стали пользоваться приложением без использования рекламы, их количество составляет 56 439 человек или 37.6 %. А вот доля платящих меньше, чем у рекламных источников, сделали заказ всего 2 % из них.
#
# Если не брать в расчет органических пользователей, то лидером из рекламных источников по общему количеству пользователей и доли платящих пользователей является 'FaceBoom'. 12 % пользователей принесли деньги компании.
#
# Меньше всего пользователей были привлечены с помощью источника 'lambdaMediaAds', всего 1.4 %, но несмотря на это, доля платящих пользователей составляет 10.5 %, что на 1.5 % меньше показателя лидера.
#
# Самая маленькая доля платящих пользователей у рекламного источника 'OppleCreativeMedia', она составляет 2.7 %, хотя пользователей привлек данный источник не так уж и мало, 8605 человек или 5.7 %.

# %% [markdown]
# ## Маркетинг ##

# %%
# Отобразим затраты по рекламным источникам

costs_channel = costs.pivot_table(index='channel', values='costs', aggfunc='sum').sort_values(by='costs', ascending=False).\
reset_index()

costs_channel
# Out:
#               channel     costs
# 0              TipTop  54751.30
# 1            FaceBoom  32445.60
# 2      WahooNetBanner   5151.00
# 3          AdNonSense   3911.25
# 4  OppleCreativeMedia   2151.25
# 5      RocketSuperAds   1833.00
# 6             LeapBob   1797.60
# 7      lambdaMediaAds   1557.60
# 8        MediaTornado    954.48
# 9             YRabbit    944.22

# %%
# Отобразим результаты на диаграмме

sns.barplot(y=costs_channel['channel'], x=costs_channel['costs'], orient='h')

plt.title('Сумма затрат по рекламным каналам', fontsize=13)

plt.xlabel('Сумма затрат', fontsize=12)

plt.ylabel('Рекламный источник', fontsize=12)
# Out:
# Text(0, 0.5, 'Рекламный источник')

# %%
# Рассчитаем общую сумму затрат на рекламу

costs_total = round(costs_channel['costs'].sum(),2)
costs_total
# Out:
# 105497.3

# %% [markdown]
# Всего на рекламу было потрачено 105 497 у.е.
#
# Больше всего средств было вложено в источник 'Tip Top', сумма составляет 54 751. Чуть меньше было вложено в источник 'FaceBoom', стоимость привлечения составляет 32 446.
#
# Меньше всего вложений было в такие источники, как 'MediaTornado', 'YRabbit', суммы затрат составляют 954 и 944 у.е. соответственно.

# %%
# Создадим отдельные столбцы в таблице 'costs' с номерами недель и месяцев для дальнейшего анализа

costs['week'] = pd.to_datetime(costs['dt']).dt.isocalendar().week
costs['month'] = pd.to_datetime(costs['dt']).dt.month

# %%
# создадим сводные таблицы для отражения динамики расходов по месяцам и по неделям

costs_month = costs.pivot_table(index='month', columns='channel', values='costs', aggfunc='sum')

costs_week = costs.pivot_table(index='week', columns='channel', values='costs', aggfunc='sum')

# %%
# Создадим 2 графика, где отразим динамику затрат по месяцам и неделям

plt.figure(figsize=(15, 8))


ax1 = plt.subplot(1,2,1)

costs_month.plot(ax=ax1)

ax1.grid(which='major', color = 'k')

plt.title('Динамика затрат по месяцам по рекламным каналам')

plt.xlabel('Номер месяца', fontsize=12)

plt.ylabel('Сумма затрат', fontsize=12)



ax2 = plt.subplot(1,2,2)

costs_week.plot(ax=ax2)

ax2.grid(which='major', color = 'k')

plt.title('Динамика затрат по неделям по рекламным каналам')

plt.xlabel('Номер недели', fontsize=12)

plt.ylabel('Сумма затрат', fontsize=12);

# %% [markdown]
# Если посмотреть на динамику затрат по месяцам и неделям, то больше всего затрат на рекламу было в такие рекламные источники, как 'Tip Top' и  'Faceboom', и с каждым новым месяцем и новой неделей расходы на рекламу продолжали расти. Пик самых высоких затрат приходился на 39 неделю у данных источников, после наблюдалось резкое снижение.  Если говорить про месяц, то самое большое вложение денежных средств было в сентябре у 'Tip Top', больше 12000 у.е., и в августе у 'Faceboom', чуть больше 6000 у.е.
#
# На третьем месте находится источник 'WahooNetBanner'. Если смотреть на первый график, то затраты стабильные, держатся примерно на уровне 1000 у.е., резких скачков не наблюдается в течение всего периода. На втором графике есть небольшие скачки, максимальная сумма затрат была на 39,40 неделях, сумма была примерно 300 у.е.
#
# В остальные рекламные источники было меньше всего вложений, резких скачков не наблюдается, в каждом новом месяце и новой неделе затраты были примерно на одном уровне.

# %%
# Определим сколько в среднем стоило привлечение одного пользователя по каждому рекламному источнику

costs_mean = profiles.pivot_table(index='channel', values='acquisition_cost', aggfunc='mean').\
reset_index().sort_values(by='acquisition_cost', ascending=False)
costs_mean
# Out:
#                channel  acquisition_cost
# 6               TipTop          2.799003
# 1             FaceBoom          1.113286
# 0           AdNonSense          1.008054
# 9       lambdaMediaAds          0.724802
# 7       WahooNetBanner          0.602245
# 5       RocketSuperAds          0.412095
# 4   OppleCreativeMedia          0.250000
# 8              YRabbit          0.218975
# 3         MediaTornado          0.218717
# 2              LeapBob          0.210172
# 10             organic          0.000000

# %%
# Построим диаграмму по сводной таблице

plt.figure(figsize=(10, 5))

sns.barplot(y=costs_mean['channel'], x=costs_mean['acquisition_cost'], orient='h')

plt.title('Затраты в среднем на привлечение одного пользователя в разбивке по источникам', fontsize=13)

plt.xlabel('Средняя сумма затрат 1 пользователя', fontsize=12)

plt.ylabel('Рекламные источники', fontsize=12);

# %% [markdown]
# Как видно из диаграммы, больше 2.5 у.е. было потрачено в среднем на привлечение одного пользователя по рекламному источнику 'Tip Top'. На втором и третьем местах 'Faceboom' и 'AdNonSense', средняя стоимость привлечения составляет 1.11 и 1 у.е. соответственно.

# %% [markdown]
# ## Оценка окупаемости рекламы ##

# %% [markdown]
# ###  Анализ окупаемости рекламы в целом ###

# %%
# Исключим из анализа данные по органическим пользователям

profiles = profiles.query('channel != "organic"')

# %%
# Определим момент анализа

observation_date = datetime(2019,11,1).date()

# Определим горизонт анализа

horizon_days = 14

# %%
# Применим функцию для расчета LTV и ROI

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days)

# %%
# Построим графики по рассчитанным метрикам

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По данным графикам можно сделать следующие выводы:
#
# - Динамика LTV показывает, что LTV стабилен, есть колебания, которые характеризуются, например, сезонным фактором.
# - Стоимость привлечения пользователей с каждым разом растет, к концу октября достигла своего максимума. Окупаемость рекламы на 14 день 'жизни пользователей' при этом снижается с каждым месяцем, в котором были привлечены пользователи. К концу октября ROI составляет примерно 70 %, хотя изначально реклама окупалась на 140 %. В целом, если посмотреть на график ROI, то рекламная кампания убыточна.

# %% [markdown]
#  ###  Анализ конверсии и удержания пользователей ###

# %%
# Рассчитаем конверсию и удержание пользователей в разбивке по устройствам

conversion_raw, conversion_device, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['device'])

retention_raw, retention_device, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['device'])

# %%
# Построим тепловую карту конверсии по устройствам

plt.figure(figsize = (27, 5))

# исключаем размеры когорт

conversion = conversion_device.drop(columns = ['cohort_size'])

sns.heatmap(conversion, annot=True, fmt='.2%', ax=plt.subplot(1, 2, 1) ) 
plt.title('Тепловая карта конверсии по устройствам');

# %%
# Построим графики конверсии в разбивке по устройствам

plot_conversion(conversion_device, conversion_history, horizon_days)

# %%
# Построим тепловую карту удержания в разбивке по устройствам, убрав размеры когорт

plt.figure(figsize=(15, 6))
sns.heatmap(retention_device.drop(columns=['cohort_size', 0]), annot=True, fmt='.2%')
plt.title('Тепловая карта удержания по устройствам')
plt.show()

# %%
# Построим графики удержания в разбивке по устройствам

plot_retention(retention_device, retention_history, horizon_days, 7)

# %% [markdown]
# Пользователи Mac хорошо конвертируются в покупателей, конверсия выше, чем у пользователей остальных устройств. Удерживаются пользователи Mac в целом хуже, чем, например, пользователи iPhone, линия пользователей Mac в большинстве своем проседает на графике.
#
# Также, стоит отметить пользователей iPhone. Конвертируются такие пользователи тоже хорошо и даже в течение 2-6 'жизни' пользователей удержание было выше, чем у пользователей Mac, но к 14 лайфтайму удержание пользователей Mac стало выше.
#
# Противоположная ситуация у пользователей PC. Конвертируются такие пользователи хуже, чем остальные, а удерживаются лучше всех на протяжении всех лайфтаймов.
#
# Удержание неплатящих пользователей по всем платформам одинаково снижается к 14 дню.

# %%
# Рассчитаем конверсию пользователей в разбивке по рекламным источникам

dimensions = ['channel']

conversion_raw, conversion_channel, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions = dimensions)

# %%
# Построим тепловую карту конверсии по устройствам

plt.figure(figsize = (27, 8))

# исключаем размеры когорт

conversion = conversion_channel.drop(columns = ['cohort_size'])

sns.heatmap(conversion, annot=True, fmt='.2%', ax=plt.subplot(1, 2, 1) ) 
plt.title('Тепловая карта конверсии по рекламным источникам');

# %%
# Построим графики конверсии в разбивке по рекламным источникам

plot_conversion(conversion_channel, conversion_history, horizon_days)

# %%
# Рассчитаем удержание пользователей в разбивке по рекламным источникам

retention_raw, retention_channel, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions = dimensions)

# %%
# Построим тепловую карту удержания в разбивке по устройствам, убрав размеры когорт

plt.figure(figsize=(20, 11))
sns.heatmap(retention_channel.drop(columns=['cohort_size', 0]), annot=True, fmt='.2%')
plt.title('Тепловая карта удержания по рекламным источникам')
plt.show()

# %%
# Построим графики удержания в разбивке по рекламным источникам

plot_retention(retention_channel, retention_history, horizon_days,7)

# %% [markdown]
# Стоит обратить внимание на рекламный источник FaceBoom. Конверсия в целом выше, чем у остальных источников, составляла примерно 12 % ( по платящим пользователям). А вот с удержанием пользователей есть проблемы, коэффициенты стабильно находятся на самом низком уровне и к 14 лайфтайму показатель составлял 1.25 %. Похожая ситуация у источника AdNonSense- конверсия у последнего лайфтайма составляла 10.8 %, но удержание платящих пользователей при этом к 14 лайфтайму составляло 2.66 %. Т.е. пользователи активно становятся покупателями, но совсем не удерживаются в данном приложении.
#
# Стоит выделить несколько источников, которые имеют хорошие результаты по платящим пользователям к 14 лайфтайму одновременно по двум показателям - конверсии и удержания. Среди них:
# - lambdaMediaAds имеет конверсию 10.36 %, удержание - 19.09 %;
# - TipTop - конверсия 9.37 %, удержание - 20.62 %;
# - RocketSuperAds - конверсия 7.36 %, удержание - 22.09 %;
# - WahooNetBanner -  конверсия 5.21 %, удержание достигло максимального значения по сравнению с остальными источникам и составило 22.9 %.

# %%
# Рассчитаем конверсию пользователей в разбивке по странам

dimensions = ['region']

conversion_raw, conversion_region, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions = dimensions)

# %%
# Построим тепловую карту конверсии по странам

plt.figure(figsize = (27, 8))

# исключаем размеры когорт

conversion = conversion_region.drop(columns = ['cohort_size'])

sns.heatmap(conversion, annot=True, fmt='.2%', ax=plt.subplot(1, 2, 1) ) 
plt.title('Тепловая карта конверсии по странам');

# %%
# Построим графики конверсии в разбивке по странам

plot_conversion(conversion_region, conversion_history, horizon_days)

# %%
# Рассчитаем удержание пользователей в разбивке по странам

retention_raw, retention_region, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions = dimensions)

# %%
# Построим тепловую карту удержания в разбивке по странам убрав размеры когорт

plt.figure(figsize=(20, 11))
sns.heatmap(retention_region.drop(columns=['cohort_size', 0]), annot=True, fmt='.2%')
plt.title('Тепловая карта удержания по странам')
plt.show()

# %%
# Построим графики удержания в разбивке по странам

plot_retention(retention_region, retention_history, horizon_days,7)

# %% [markdown]
# Пользователи США хорошо конвертируются в покупателей, конверсия достигает к 14 лайфтайму 9.6 %. Удерживаются такие пользователи хуже других, коэффициент удержания  опустился к 14 лайфтайму и составил 8.95%. Для сравнения пользователи из Англии и Франции удерживаются намного лучше других, их коэффициенты удержания к 14 лайфтайму находятся на уровне 17 %, а конверсии составляют при этом примерно 5 %.

# %% [markdown]
# ###  Анализ LTV, ROI, CAC  по различным признакам ###

# %%
# Рассчитаем LTV, CAC, ROI в разбивке по странам

dimensions = ['region']

ltv_raw, ltv_region, ltv_history, roi_region, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

# %%
# Построим графики в разбивке по странам

plot_ltv_roi(
    ltv_region, ltv_history, roi_region, roi_history, horizon_days, window=14
)

# %% [markdown]
# Пользователи из США приносят больше прибыли,чем пользователи из других стран. 1 пользователь из США приносит в среднем доход 1 у.е., а все остальные пользователи меньше 0,8 у.е. Но вот с окупаемостью рекламы по пользователям из США дела обстоят совсем неоптимистично. Реклама не окупается, так как затраты почти в 2 раза превышают доходы к концу октября.
#
# Лучший показатель по окупаемости рекламы - у пользователей из Англии. Реклама окупилась на 160 %. Также, реклама окупилась примерно на 150% по пользователям из Германии и Франции.
#
# Если посмотреть на динамику ROI , то можно отметить, что реклама стабильно окупается во всех странах на протяжении всех когорт, кроме США.
#
# Средний доход на 1 пользователя по всем остальным странам находится в пределех от 0,6 до 0,8 у.е. Затраты на привлечение при этом с июня снизились у всех стран, кроме США, и были примерно стабильными до конца рассматриваемого периода.

# %%
# Рассчитаем LTV, CAC, ROI в разбивке по рекламным каналам

dimensions = ['channel']

ltv_raw, ltv_channel, ltv_history, roi_channel, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

# %%
# Построим графики в разбивке по рекламным каналам

plot_ltv_roi(
    ltv_channel, ltv_history, roi_channel, roi_history, horizon_days, window=14
)

# %%
# Построим тепловую карту ROI по рекламным каналам

plt.figure(figsize=(20, 11))
sns.heatmap(roi_channel.drop(columns=['cohort_size', 0]), annot=True, fmt='.2%')
plt.title('Тепловая карта ROI по рекламным каналам')
plt.show()

# %% [markdown]
# Рекламная кампания большинства источников окупилась. Лидером является источник YRabbit, окупаемость рекламы составила 257.8 %, при этом затраты на привлечение пользователей имеют стабильный характер, и сумма затрат находится  примерно на уровне 0,25 у.е.
#
# Вложения в такие рекламные источники, как AdNonSense, FaceBoom, TipTop, не оправдались, рекламная кампания оказалась убыточна. Показатели ROI данных каналов привлечения находятся в пределах от 50 до 80 %. Также,следует отметить, что расходы в источник TipTop активно увеличивались на протяжении всего периода и к концу октября привлечение одного пользователя обходилось 3,5 у.е.
# А вот доход от одного пользователя составлял 1,5 у.е.
#
# Хорошие результаты были получены от канала lambdaMediaAds. Во-первых, реклама по данному источнику окупилась и достигла значения - 242.9 %. Во-вторых, доход от одного пользователя достиг 1.75 у.е. В-третьих, расходы были в течение всего периода стабильными и держались на уровне примерно 0.75 у.е.

# %%
# Рассчитаем LTV, CAC, ROI в разбивке по устройствам

dimensions = ['device']

ltv_raw, ltv_device, ltv_history, roi_device, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

# %%
# Построим графики в разбивке по устройствам

plot_ltv_roi(
    ltv_device, ltv_history, roi_device, roi_history, horizon_days, window=14
)

# %% [markdown]
# Реклама окупается только у пользователей PC, но если посмотреть на динамику ROI по когортам,то можно заметить, как к концу октября реклама не окупалась ни по одному устройству.
#
# Расходы по всем устройствам в течение всего периода растут вверх,больше затрат было по отошению к пользователям Mac и iPhone, сумма затрат достигла максимального значения 1,5 у.е.
#
# LTV у всех устройств примерно находятся на одном уровне и не превышает 1 у.е.

# %% [markdown]
# ### Выводы по 5 разделу ###

# %% [markdown]
# В данном разделе были проведены расчеты по основным бизнес-метрикам по разным признакам пользователей - по странам, по устройствам, по рекламным источникам.
#
# Рекламная кампания оказалась в целом убыточна.
#
# Для того, чтобы дать рекомендации, необходимо посмотреть на картину в целом и объединить результаты, которые были получены по разным признакам пользователей. Для этого построим итоговые таблицы.

# %% [markdown]
# ***Посмотрим на бизнес-метрики в разбивке по рекламным каналам***

# %%
# Удалим органических пользователей и оставим столбцы,необходимые для анализа

users_channel.drop([0], axis=0, inplace=True)
users_channel = users_channel[['channel', 'Всего пользователей', 'Доля платящих, %']]

# %%
# Оставим в таблице платящих пользователей на 14 день 'жизни' и отобразим удержание в процентах

retention_channel = retention_channel.reset_index().query('payer != False')[['channel', 13]].\
rename(columns={13: 'Удержание, %'})

retention_channel['Удержание, %'] = retention_channel['Удержание, %'] * 100

# %%
# Оставим в таблице платящих пользователей на 14 день 'жизни' и отобразим конверсию в процентах

conversion_channel = conversion_channel.reset_index()[['channel', 13]].rename(columns={13: 'Конверсия, %'})

conversion_channel['Конверсия, %'] = conversion_channel['Конверсия, %'] * 100

# %%
# Оставим в таблице платящих пользователей на 14 день 'жизни'

ltv_channel = ltv_channel.reset_index()[['channel', 13]].rename(columns={13: 'LTV'})

# %%
# Оставим в таблице платящих пользователей на 14 день 'жизни' и отобразим возврат от инвестиций в процентах

roi_channel = roi_channel.reset_index()[['channel', 13]].rename(columns={13: 'ROI, %'})

roi_channel['ROI, %'] = roi_channel['ROI, %'] * 100

# %%
# Соединим несколько полученных таблиц ранее

data_channel = users_channel.merge(retention_channel, on=['channel'], how='left')
data_channel = data_channel.merge(conversion_channel, on=['channel'], how='left')
data_channel = data_channel.merge(ltv_channel, on=['channel'], how='left')
data_channel = data_channel.merge(roi_channel, on=['channel'], how='left')

# Рассчитаем CAC на 14 день 'жизни' пользователей и сохраним результаты в отдельном столбце

data_channel['CAC'] = data_channel['LTV'] / (data_channel['ROI, %'] / 100)

data_channel
# Out:
#               channel  Всего пользователей  Доля платящих, %  Удержание, %  \
# 0            FaceBoom                29144         12.204914      1.249256
# 1              TipTop                19561          9.600736     20.616246
# 2  OppleCreativeMedia                 8605          2.707728     21.363636
# 3             LeapBob                 8553          3.063253     20.987654
# 4      WahooNetBanner                 8553          5.296387     22.897196
# 5      RocketSuperAds                 4448          7.913669     22.089552
# 6        MediaTornado                 4364          3.574702     12.162162
# 7             YRabbit                 4312          3.826531     10.256410
# 8          AdNonSense                 3880         11.340206      2.663438
# 9      lambdaMediaAds                 2149         10.469986     19.090909
#
#    Конверсия, %       LTV      ROI, %       CAC
# 0     11.937264  0.821469   73.778955  1.113419
# ...

# %% [markdown]
# Больше всего пользователей пришли в приложение из рекламных источников FaceBoom, Tip Top. Это очень хорошие результаты. Но есть проблема с окупаемостью рекламы. ROI меньше 100 %, значит рекламная кампания была убыточна.
#
# Пользователи из канала FaceBoom, можно сказать, совсем не возвращались в приложение, а вот пользователи TipTop,наоборот, возвращались активно.  Также, пользователи обоих источников активно конвертировались в покупателей. А вот с затратами на рекламу есть проблемы. Вложения в FaceBoom и TipTop очень высокие по сравнению с  доходом. Так как, пользователи из канала TipTop активно переходят в приложение, приносят высокий доход и хорошо удерживаются, то такой канал привлечения важен, но для того, чтобы рекламная кампания была успешной, затраты на привлечение пользователей необходимо снизить за счет перераспределения бюджета на каналы с меньшим CAC.
#
# Что касается источника FaceBoom, то, в первую очередь, необходимо увеличить LTV. Данный источник привлек больше всего пользователей, но принесли доход всего 12 % из них. Это могло быть связано,например, с тем, что приложение не дало то, что обещала реклама. Для того, чтобы понять, как удержать пользователей и увеличить в итоге LTV, необходимо собрать отзывы, оценки по нескольким критериям (например, работа приложения, удобство оплаты, ассортимент товара/услуг, их качество). После, на основе собранных данных, запустить кампанию повторного вовлечения, чтобы предотвратить отток пользователей. То же самое можно сделать по отношению к источнику AdNonSense.
#
# Источник lambdaMediaAds привлек 2149 человек, 10 % из которых принесли доход выше,чем пользователи из FaceBoom, а также которые чаще возвращались в приложение, неплохо конвертировались в покупателей, и затраты при этом оставались стабильными и на оптимальном уровне. Стоит обратить внимание на данный источник привлечения пользователей и увеличить инвестиции в него.
#
# К перспективным источникам можно отнести также RocketSuperAds и WahooNetBanner. Доля платящих составляет 7% и 5 % соответственно, пользователи активно возвращаются в приложение, неплохо конвертируются в покупателей, принесли доход 0,9 у.е., имеют стабильные и оптимальные затраты на рекламу и, наконец, рекламная кампания окупилась на 224 % и 153 % соответственно. В данные источники можно попробовать увеличить вложения.
#
# Для развития перспективных каналов привлечения необходимо перераспределить бюджет в целом - приостановить инвестирование в менее прибыльные рекламные источники такие, как 'MediaTornado', 'YRabbit', 'LeapBob', 'OppleCreativeMedia'

# %% [markdown]
# ***Теперь посмотрим на бизнес-метрики в разбивке по странам***

# %%
users_region = users_region[['region', 'Всего пользователей', 'Доля платящих, %']]

# Оставим в таблице платящих пользователей на 14 день 'жизни' и отобразим удержание в процентах

retention_region = retention_region.reset_index().query('payer != False')[['region', 13]].\
rename(columns={13: 'Удержание, %'})

retention_region['Удержание, %'] = retention_region['Удержание, %'] * 100

# Оставим в таблице платящих пользователей на 14 день 'жизни' и отобразим конверсию в процентах

conversion_region = conversion_region.reset_index()[['region', 13]].rename(columns={13: 'Конверсия, %'})

conversion_region['Конверсия, %'] = conversion_region['Конверсия, %'] * 100

# Оставим в таблице платящих пользователей на 14 день 'жизни'

ltv_region = ltv_region.reset_index()[['region', 13]].rename(columns={13: 'LTV'})

# Оставим в таблице платящих пользователей на 14 день 'жизни' и отобразим возврат от инвестиций в процентах

roi_region = roi_region.reset_index()[['region', 13]].rename(columns={13: 'ROI, %'})

roi_region['ROI, %'] = roi_region['ROI, %'] * 100

# %%
# Соединим несколько полученных таблиц ранее

data_region = users_region.merge(retention_region, on='region', how='left')
data_region = data_region.merge(conversion_region, on='region', how='left')
data_region = data_region.merge(ltv_region, on='region', how='left')
data_region = data_region.merge(roi_region, on='region', how='left')

# Рассчитаем CAC на 14 день 'жизни' пользователей и сохраним результаты в отдельном столбце

data_region['CAC'] = data_region['LTV'] / (data_region['ROI, %'] / 100)

data_region
# Out:
#           region  Всего пользователей  Доля платящих, %  Удержание, %  \
# 0  United States               100002          6.901862      8.952644
# 1             UK                17575          3.982930     17.790262
# 2         France                17450          3.799427     17.399618
# 3        Germany                14981          4.111875     13.490364
#
#    Конверсия, %       LTV      ROI, %       CAC
# 0      9.606912  1.001316   68.777552  1.455876
# 1      4.916477  0.743481  163.430576  0.454922
# 2      4.840243  0.670278  145.764361  0.459836
# 3      5.049834  0.713019  153.370868  0.464898

# %% [markdown]
# Больше всего пользователей из США, которые стали пользоваться приложением. Но такие пользователи плохо удерживаются и приносят мало дохода, поэтому рекламная кампания убыточна. Причины могут быть разные,например, сложности с оплатой, неинтересный контент, высокие цены. Для того, чтобы удержать пользователей и ,соответственно, в дальнейшем увеличить конверсию, необходимо провести опрос среди пользователей и выяснить, что людям не нравится, какие есть проблемы. А затем делать выгодные для них предложения.

# %% [markdown]
# ***Теперь посмотрим на бизнес-метрики в разбивке по устройствам***

# %%
users_device = users_device[['device', 'Всего пользователей', 'Доля платящих, %']]

# Оставим в таблице платящих пользователей на 14 день 'жизни' и отобразим удержание в процентах

retention_device = retention_device.reset_index().query('payer != False')[['device', 13]].\
rename(columns={13: 'Удержание, %'})

retention_device['Удержание, %'] = retention_device['Удержание, %'] * 100

# Оставим в таблице платящих пользователей на 14 день 'жизни' и отобразим конверсию в процентах

conversion_device = conversion_device.reset_index()[['device', 13]].rename(columns={13: 'Конверсия, %'})

conversion_device['Конверсия, %'] = conversion_device['Конверсия, %'] * 100

# Оставим в таблице платящих пользователей на 14 день 'жизни'

ltv_device = ltv_device.reset_index()[['device', 13]].rename(columns={13: 'LTV'})

# Оставим в таблице платящих пользователей на 14 день 'жизни' и отобразим возврат от инвестиций в процентах

roi_device = roi_device.reset_index()[['device', 13]].rename(columns={13: 'ROI, %'})

roi_device['ROI, %'] = roi_device['ROI, %'] * 100

# %%
# Соединим несколько полученных таблиц ранее

data_device = users_device.merge(retention_device, on='device', how='left')
data_device = data_device.merge(conversion_device, on='device', how='left')
data_device = data_device.merge(ltv_device, on='device', how='left')
data_device = data_device.merge(roi_device, on='device', how='left')

# Рассчитаем CAC на 14 день 'жизни' пользователей и сохраним результаты в отдельном столбце

data_device['CAC'] = data_device['LTV'] / (data_device['ROI, %'] / 100)

data_device
# Out:
#     device  Всего пользователей  Доля платящих, %  Удержание, %  Конверсия, %  \
# 0   iPhone                54479          6.207897      9.181495      8.495917
# 1  Android                35032          5.851793     10.737463      7.992071
# 2       PC                30455          5.046790     12.417219      6.536849
# 3      Mac                30042          6.364423     11.083281      8.705697
#
#         LTV      ROI, %       CAC
# 0  0.916983   71.806415  1.277021
# 1  0.912098   89.442499  1.019759
# 2  0.836167  105.480134  0.792724
# 3  0.930541   72.913891  1.276219

# %% [markdown]
# Стоит обратить внимание, что рекламная кампания в разбивке по устройствам не окупается, кроме устройства PC.
# Больше всего вложений делается в пользователей iPhone, Mac, Android. Больше 1 у.е. тратится на привлечение одного пользователя, а на выходе получаем невысокий процент платящих пользователей, удержания, дохода и ,в конечном счете, получаем убытки. Необходимо удержать пользователей, которые уже скачали приложение. Выявить их интересы, какой контент более популярный, а затем персонализировать рекламные предложения, исходя из выявленных потребностей. Также, на основе выявленных интересов среди текущих пользователей, пересмотреть целевую аудиторию в целом для проведения дальнейшей рекламной кампании.

# %% [markdown]
# ## Выводы ##

# %% [markdown]
# Было проведено много разных расчетов, которые позволили выявить проблемы с окупаемостью рекламы у приложения Procrastinate Pro+.
#
# Были рассчитаны следующие важные бизнес-метрики:
#
# - **Конверсия**
# - **Удержание**
# - **LTV ('пожизненная ценность' клиента)**
# - **CAC (стоимость привлечения одного клиента)**
# - **ROI (окупаемость инвестиций)**
#
# Основными причинами неэффективности привлечения пользователей стали:
#
# 1. Вложения в рекламные источники, которые не принесли высокого дохода.
#
# 2. Незнание того,что хотят клиенты или что им не нравится в приложении, как следствие, - стремительное снижение коэффициента удержания с каждым новым лайфтаймом.
#
# 3. Увеличение вложений только в те ресурсы, которые привлекают больше пользователей.
#
#
# `Рекомендации для отдела маркетинга следующие:`
#
# 1. Приостановить инвестирование в менее прибыльные рекламные источники такие, как 'MediaTornado', 'YRabbit', 'LeapBob', 'OppleCreativeMedia'.
#
#
# 2. Высокие затраты на привлечение пользователей необходимо снизить за счет перераспределения бюджета на каналы с меньшим CAC, т.е. направить средства в перспективные каналы.
#
#
# 3. Выявить причины, по которым пользователи плохо удерживаются. Необходимо собрать отзывы, оценки по нескольким критериям (например, работа приложения, удобство оплаты, ассортимент товара/услуг, их качество). После, на основе собранных данных, запустить кампанию повторного вовлечения, чтобы предотвратить отток пользователей.
#
#
# 4. Пересмотреть целевую аудиторию для проведения дальнейшей рекламной кампании, т.е. на основе выявленных потребностей текущих пользователей определить, кому лучше всего показывать рекламу.
#
#
# 5. Вкладывать больше средств в перспективные рекламные источники такие, как RocketSuperAds, WahooNetBanner, lambdaMediaAds.
#
#
# 6. Сделать акцент на привлечение пользователей из Франции, Германии, Англии.
